# %% [markdown]
# This is a step by step guide for web scraping using BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup
import re
import csv
from http.client import RemoteDisconnected

# %%
categories_path = [
    "Immobilier", 
    "ImmoNeuf/Immobilier%20Neuf"
]
base_url = "https://www.tayara.tn/ads/c/{}/?page={}"

def get_all_soup():
    soups = []
    for category in categories_path:
        for page in range(1, 50):  # Limiter à 5 pages pour l'exemple
            url = base_url.format(category, page)
            # print(url)
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'html.parser')
            soups.append(soup)
    return soups

# %%
# permet de retourner tous les liens de chaque immobilier
# vs pouvez inspecter https://www.tayara.tn/item/66eae8a467b755ba922a2a58/Immobilier%20Neuf/Ariana/Ghazela/Appartement_en_S2_de_12880_m_A41_au_4me_tage/
def get_all_links(soup):
    property_links = []
    for article in soup.find_all('article', class_="mx-0"):
        link = article.find('a')['href']
        if '/item/' in link:
            full_url = "https://www.tayara.tn" + link
            property_links.append(full_url)
    return property_links

# %%
global_features = {} # contient toutes les caractéristiques possibles des biens immobiliers

def crawl_property_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    item_info = {}

    try:
        # Titre
        title_element = soup.find('h1', class_='text-gray-700 font-bold text-2xl font-arabic')
        if not title_element:
            # annonce gnrlmnt supprimée, ntaffiwha
            print(f"Titre non disponible pour l'URL: {url}, annonce ignorée.")
            return None
        title = title_element.text.strip()

        # Configuration des pièces
        pieces = re.search(r'S\+\d+', title)
        pieces_value = pieces.group() if pieces else None

        # Récupérer les parties du prix
        price_parts = soup.find_all('span', class_='mr-1')
        price = ''.join([part.text.strip() for part in price_parts if part.text.strip().isdigit()])

        # Localisation
        location_element = soup.find('div', class_='flex items-center space-x-2 mb-1')
        if location_element:
            location = location_element.text.strip().split(',')[0].strip()
        else:
            location = None

        # Ajouter les informations de base
        item_info['Annonce'] = title
        item_info['Prix'] = price
        item_info['Localisation'] = location
        item_info['Configuration des pièces'] = pieces_value

        # Ajouter dynamiquement les nouvelles clés à item_info
        criterias = soup.find_all('span', class_='text-gray-600/80 text-2xs md:text-xs lg:text-xs font-medium')
        values = soup.find_all('span', class_='text-gray-700/80 text-xs md:text-sm lg:text-sm font-semibold')

        # Associer chaque critère à sa valeur
        for criteria, value in zip(criterias, values):
            criterion_text = criteria.text.strip()
            value_text = value.text.strip()

            if criterion_text:
                # Ajouter la nouvelle clé à item_info
                item_info[criterion_text] = value_text
                # Ajouter cette clé dans global_features si elle n'existe pas encore
                if criterion_text not in global_features:
                    global_features[criterion_text] = 'False'

        # Vérifier si toutes les clés de global_features sont présentes dans item_info
        for feature in global_features:
            if feature not in item_info:
                item_info[feature] = 'False'
            

        return item_info

    except AttributeError as e:
        print(f"Erreur d'extraction à l'URL: {url} - {str(e)}")
        return None

# %%
property_links = []
for soup in get_all_soup():
    property_link = get_all_links(soup)
    property_links.extend(property_link)
print(property_links)
 # Exemple avec le lien https://www.tayara.tn/item/66eae8a467b755ba922a2a58/Immobilier%20Neuf/Ariana/Ghazela/Appartement_en_S2_de_12880_m_A41_au_4me_tage/
# data = crawl_property_page(property_links[0])
# print(data)
# Out:
# ['https://www.tayara.tn/item/673c81c23c20a99fb553d9a1/Terrains%20et%20Fermes/Ariana/Raoued/Terrain_A_vendre_240M_/', 'https://www.tayara.tn/item/673c81be3c20a99fb553d99c/Locations%20de%20vacances/Sousse/Kantaoui/location_vacances/', 'https://www.tayara.tn/item/673c81960d8480a1e01226e8/Locations%20de%20vacances/Sousse/Khzema/par_nuite/', 'https://www.tayara.tn/item/673c81900d8480a1e01226e3/Appartements/Ariana/Ennasr/ENNASR_1_APPARTEMENT_S2_A_LOUER_/', 'https://www.tayara.tn/item/673c81733c20a99fb553d961/Locations%20de%20vacances/Sousse/Sousse/location_vacances_/', 'https://www.tayara.tn/item/673c816f0d8480a1e01226bf/Appartements/Ariana/El_Menzah_8/appartement_s2_Menzah_8/', 'https://www.tayara.tn/item/673c81513c20a99fb553d945/Maisons%20et%20Villas/Ariana/Les_Jardins_El_Menzah_2/REZDECHAUSSE_DE_VILLA_S4_AUX_JARDINS_DEL_MENZAH_2/', 'https://www.tayara.tn/item/673c81030d8480a1e0122658/Appartements/Sousse/Sahloul/appartement_de_type_S2_situ_sahloul/', 'https://www.tayara.tn/item/673c81483c20a99fb553d934/Appartements/Tunis/L_Aouina/a_louer_s1_a_cite_wahat_avec_place_parking_ss/', 'https://www.tayara.tn/item/673c813d0d8480a1e0122692/Appartements/Sfax/Sfax_Ville/_/', 'https://www.tayara.tn/item/673c81350d8480a1e012268c/Locations%20de%20vacances/Sousse/Khzema/_22707177Une_bonne_affaire_pour_profiter_des_vacances_a_sousse_A_louer_par_nuite/', 'https://www.tayara.tn/item/673c812e0d8480a1e0122684/Appartements/Ariana/Cit_Ennasr_2/appartement_s1_Ennasr_2/', 'https://www.tayara.tn/item/673c812b3c20a99fb553d912/Appartements/Tunis/Ain_Zaghouen/A_vendre_un_magnifique_appartement_s2_a_ain_Zaghouan_avec_abri_voiture_/', 'https://www.tayara.tn/item/673c810e0d8480a1e0122666/Appartements/Tunis/L_Aouina/A_vendre_un_appartement_s2_aux_jardins_de_laouina_/', 'https://www.tayara.tn/item/673c80fc3c20a99fb553d8d8/Appartements/Ariana/Ariana/ARIANA_APPARTEMENT_S2_A_LOUER_/', 'https://www.tayara.tn/item/673c80f70d8480a1e0122643/Appartements/Tunis/L_Aouina/a_vendre_un_magnifique_appartement_s3_a_laouina_cit_wahat_/', 'https://www.tayara.tn/item/673c80db3c20a99fb553d8b7/Appartements/Tunis/Ain_Zaghouen/a_vendre_un_appartement_au_rdc_a_ain_zaghouan_avec_place_parking_soussol_/', 'https://www.tayara.tn/item/673c80d90d8480a1e012262a/Appartements/Tunis/El_Menzah_9/MENZAH_9_C_APPARTEMENT_S1_LOUER_/', 'https://www.tayara.tn/item/673354a60d8480a1e00c75f3/Appartements/Tunis/Jardins_De_Carthage/A_VENDRE_S1_JARDINS_DE_CARTHAGE_58713586_FB7062/', 'https://www.tayara.tn/item/673c80b90d8480a1e012260e/Appartements/Tunis/L_Aouina/A_louer_S2/', 'https://www.tayara.tn/item/673c80b93c20a99fb553d896/Maisons%20et%20Villas/Tunis/Lac_1/LES_BERGES_DU_LAC_1_VILLA_S5/', 'https://www.tayara.tn/item/673c80a63c20a99fb553d87d/Bureaux%20et%20Plateaux/Ben_Arous/Medina_Jedida/Local_Commercial_de_79_m2/', 'https://www.tayara.tn/item/673b26010d8480a1e011474d/Appartements/Tunis/L_Aouina/A_LOUER_S2_EL_WAHAT_TEL_58713586_FB7085/', 'https://www.tayara.tn/item/673c809a0d8480a1e01225ed/Appartements/Ariana/Cit_Ennasr_2/_ENNASR_2_ETAGE_DE_VILLA_S2_AVEC_SJOUR_A_LOUER_/', 'https://www.tayara.tn/item/673c80950d8480a1e01225e4/Bureaux%20et%20Plateaux/Nabeul/Hammamet/CoverZone_Housse_Bche_Bateau_Jetski_pneumatique_Seadoo_Yacht_Yamaha_Semi_rigide/', 'https://www.tayara.tn/item/673c80930d8480a1e01225db/Terrains%20et%20Fermes/Kairouan/Kairouan/A_VENDRE_TERRAIN_400M2_MANSOURA_KAIROUAN_AVEC_TITRE_FONCIER_AU_LOTISSEMENT_APPROUVE_A_EL_MANSOURA_PRES_DE_LHOPITAL_ELSELMEN_ET_LA_FUTURE_VILLE_MEDICALE/', 'https://www.tayara.tn/item/673c80783c20a99fb553d843/Maisons%20et%20Villas/Ben_Arous/El_Mourouj_6/opportunit_pour_un_terrain_a_mourouj_6_/', 'https://www.tayara.tn/item/673c80743c20a99fb553d83e/Appartements/Tunis/Alain_Savary/_ALAIN_SAVARY_BUREAU_H2_LOUER_/', 'https://www.tayara.tn/item/66b23dba37137099bb848e42/Appartements/Tunis/Jardins_De_Carthage/A_VENDRE_S2_JARDINS_DE_CARTHAGE_TEL_58713586_FB6078/', 'https://www.tayara.tn/item/673c80513c20a99fb553d808/Appartements/Ariana/Les_Jardins_El_Menzah_1/un_rdc_de_villa_s3_au ...

# %%
print(property_links.__len__())
# Out:
# 1667

# %%
def save_to_csv(data, filename="immobiliers.csv"):
    if not data:
        print("Aucune donnée à sauvegarder.")
        return

    # Créer un ensemble pour les fieldnames
    fieldnames = set()

    # Passer par toutes les annonces et ajouter dynamiquement les champs
    for row in data:
        if row:  # Vérifier que la ligne n'est pas vide
            fieldnames.update(row.keys())  # Ajouter toutes les clés des données à fieldnames

    # Convertir l'ensemble en une liste pour avoir une structure ordonnée
    fieldnames = list(fieldnames)

    try:
        with open(filename, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writeheader()
            for row in data:
                if row:  # Vérifier que la ligne n'est pas vide
                    writer.writerow(row)

    except PermissionError:
        print(f"Erreur: permission refusée pour écrire dans le fichier {filename}.")
    except Exception as e:
        print(f"Erreur lors de l'enregistrement des données : {e}")

# %%
data = []
for link in property_links:
    try:
        data.append(crawl_property_page(link))
    except requests.exceptions.ConnectionError as e:
        print(f"Connection error: {e}")
    except requests.exceptions.RequestException as e:
        print(f"Other error: {e}")
    except RemoteDisconnected as e:
        print(f"Remote disconnected: {e}")
save_to_csv(data, "immobiliers.csv")
# Out:
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c80f70d8480a1e0122643/Appartements/Tunis/L_Aouina/a_vendre_un_magnifique_appartement_s3_a_laouina_cit_wahat_/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c80db3c20a99fb553d8b7/Appartements/Tunis/Ain_Zaghouen/a_vendre_un_appartement_au_rdc_a_ain_zaghouan_avec_place_parking_soussol_/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c80b90d8480a1e012260e/Appartements/Tunis/L_Aouina/A_louer_S2/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c7c9f0d8480a1e0122276/Maisons%20et%20Villas/Ariana/La_Soukra/_a_vendre_une_villa_S3_avec_piscine_a_la_soukra_/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c7c7d3c20a99fb553d4d6/Appartements/Tunis/L_Aouina/A_vendre_des_appartements_direct_promoteur_haut_standing_a_la_nouvelle_soukra/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c6a693c20a99fb553c36a/Appartements/Tunis/L_Aouina/a_louer_s1_par_nuite_/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c69b60d8480a1e0121086/Appartements/Tunis/Jardins_De_Carthage/A_vendre_un_spacieux_Duplex_S3_aux_jardins_de_carthage/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c69830d8480a1e0121057/Appartements/Tunis/L_Aouina/A_louer_S1_A_CITE_EL_WAHAT/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c696a3c20a99fb553c245/Appartements/Tunis/L_Aouina/a_vendre_des_appartement_s2_s3_direct_promoteur_/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c69470d8480a1e0121016/Appartements/Tunis/L_Aouina/opportunit_a_vendre_s2_jardin_de_laouina/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c61ba3c20a99fb553ba99/Appartements/Tunis/L_Aouina/A_louer_S1_meubl_haut_par_nuite_laouina_cit_wahat_/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c4ff63c20a99fb553aa2d/Appartements/Tunis/L_Aouina/A_vendre_des_appartements_S1_direct_promoteur/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c4fda0d8480a1e011f8bf/Maisons%20et%20Villas/Zaghouan/Bir_Mchergua/_Vendre_Maison_dhte_JBEL_LOUEST/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c4fb90d8480a1e011f892/Appartements/Tunis/L_Aouina/_Vendre_NOUVEAUX_APPARTEMENTS_S1_S2_S3_ET_DES_DUPLEX_DIRECT_PROMOTEUR_/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c4f7f0d8480a1e011f854/Appartements/Tunis/L_Aouina/_Louer_Un_appartement_S3_situ_Cit_Wahat/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c4f630d8480a1e011f837/Appartements/Tunis/L_Aouina/_Vendre_NOUVEAUX_APPARTEMENTS_S1_S2_DIRECT_PROMOTEUR_/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c4f373c20a99fb553a989/Appartements/Tunis/L_Aouina/_Vendre_Un_S2_situ_Jardin_lAouina/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c4ef03c20a99fb553a94d/Bureaux%20et%20Plateaux/Ariana/La_Soukra/_Louer_Appartement_Usage_bureautique_Spacieux_situ_La_Soukra/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c4e9c0d8480a1e011f76c/Appartements/Tunis/L_Aouina/_vendre_Un_appartement_S2_situ_Cit_Wahat/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c4e823c20a99fb553a8e5/Appartements/Tunis/L_Aouina/_Louer_Un_appartement_S1_situ_la_Nouvelle_Soukra/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c4e5a0d8480a1e011f72a/Appartements/Ariana/La_Soukra/A_Vendre_Un_appartement_S2_Direct_promoteur_situ_La_Nouvelle_Soukra_/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673c3b880d8480a1e011ea41/Appartements/Ben_Arous/Rads/Etage_de_villa_S3_Rades_Meliene/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673bb3bb0d8480a1e011c8f3/Appartements/Tunis/L_Aouina/A_louer_S1_Neuf_a_cit_el_wahat/, annonce ignorée.
# Titre non disponible pour l'URL: https://www.tayara.tn/item/673b4c5f0d8480a1e0116d5d/Appartements/Tunis/Tunis/_/, annonce ignorée.
